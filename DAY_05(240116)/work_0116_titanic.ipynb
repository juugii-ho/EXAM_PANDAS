# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.isna().sum() 
# age는 가능한 경우에만 사용, embarked는 NaN 삭제, deck은 삭제
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic = titanic.dropna(axis='columns')
# titanic = titanic.dropna(subset = ['embarked', 'embark_town'])
titanic
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %%
titanic.isna().sum() 
# age는 가능한 경우에만 사용, embarked는 NaN 삭제, deck은 삭제
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    object
#  3   sibsp       891 non-null    int64
#  4   parch       891 non-null    int64
#  5   fare        891 non-null    float64
#  6   class       891 non-null    object
#  7   who         891 non-null    object
#  8   adult_male  891 non-null    bool
#  9   alive       891 non-null    object
#  10  alone       891 non-null    bool
# dtypes: bool(2), float64(1), int64(4), object(4)
# memory usage: 64.5+ KB

# %%
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: fare, Length: 891, dtype: bool

# %%
# titanic['survived'].unique()
sur = (titanic['survived']==1).sum()
dth = (titanic['survived']==0).sum()
# titanic['pclass'].unique()
p1 = (titanic['pclass']==1).sum()
p2 = (titanic['pclass']==2).sum()
p3 = (titanic['pclass']==3).sum()
# titanic['sex'].unique()
male = (titanic['sex']=='male').sum()
female = (titanic['sex']=='female').sum()
# titanic['sibsp'].unique()
sib0 = (titanic['sibsp']==0).sum()
sib1 = (titanic['sibsp']==1).sum()
sib2 = (titanic['sibsp']==2).sum()
sib3 = (titanic['sibsp']==3).sum()
sib4 = (titanic['sibsp']==4).sum()
sib5 = (titanic['sibsp']==5).sum()
sib6 = (titanic['sibsp']==8).sum()
# titanic['parch'].unique()
par0 = (titanic['parch']==0).sum()
par1 = (titanic['parch']==1).sum()
par2 = (titanic['parch']==2).sum()
par3 = (titanic['parch']==3).sum()
par4 = (titanic['parch']==4).sum()
par5 = (titanic['parch']==5).sum()
par6 = (titanic['parch']==6).sum()
# titanic['fare'].nunique()
listSPSSP= [sur, dth, p1, p2, p3, male, female, sib0, sib1, sib2, sib3, sib4, sib5, sib6, par0, par1, par2, par3, par4, par5, par6]
# listSPSSP2= ["sur", "dth", "p1", p2, p3, male, female, sib0, sib1, sib2, sib3, sib4, sib5, sib6, par0, par1, par2, par3, par4, par5, par6]


listSurvived = [sur, dth]
listPclass = [p1, p2, p3]
listSex = [male, female]
listSibsp = [sib0, sib1, sib2, sib3, sib4, sib5, sib6]
listPar = [par0, par1, par2, par3, par4, par5, par6]

listTotal = listSurvived + listPclass + listSex + listSibsp + listPar
listTotal2 = ["sur", "dth", "pcl1", "pcl2", "pcl3", "male", "female", "sib0", "sib1", "sib2", "sib3", "sib4", "sib5", "sib6", "par0", "par1", "par2", "par3", "par4", "par5", "par6"]

listTitanic = []
dictTitanic = {}

i=-1
k=0
for l in listTotal:
    i +=1
    for m in listTotal:
        print(f'{listTotal2[k]}/{listTotal2[i]} =>{round(l/m, 1)}')
        k += 1
    k=0
# Out:
# sur/sur =>1.0
# dth/sur =>0.6
# pcl1/sur =>1.6
# pcl2/sur =>1.9
# pcl3/sur =>0.7
# male/sur =>0.6
# female/sur =>1.1
# sib0/sur =>0.6
# sib1/sur =>1.6
# sib2/sur =>12.2
# sib3/sur =>21.4
# sib4/sur =>19.0
# sib5/sur =>68.4
# sib6/sur =>48.9
# par0/sur =>0.5
# par1/sur =>2.9
# par2/sur =>4.3
# par3/sur =>68.4
# par4/sur =>85.5
# par5/sur =>68.4
# par6/sur =>342.0
# sur/dth =>1.6
# dth/dth =>1.0
# pcl1/dth =>2.5
# pcl2/dth =>3.0
# pcl3/dth =>1.1
# male/dth =>1.0
# female/dth =>1.7
# sib0/dth =>0.9
# sib1/dth =>2.6
# sib2/dth =>19.6
# sib3/dth =>34.3
# sib4/dth =>30.5
# sib5/dth =>109.8
# sib6/dth =>78.4
# par0/dth =>0.8
# par1/dth =>4.7
# par2/dth =>6.9
# par3/dth =>109.8
# par4/dth =>137.2
# par5/dth =>109.8
# par6/dth =>549.0
# sur/pcl1 =>0.6
# dth/pcl1 =>0.4
# pcl1/pcl1 =>1.0
# pcl2/pcl1 =>1.2
# pcl3/pcl1 =>0.4
# male/pcl1 =>0.4
# female/pcl1 =>0.7
# sib0/pcl1 =>0.4
# sib1/pcl1 =>1.0
# sib2/pcl1 =>7.7
# sib3/pcl1 =>13.5
# sib4/pcl1 =>12.0
# sib5/pcl1 =>43.2
# sib6/pcl1 =>30.9
# ...

# %%
# titanic.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[222], line 2
#       1 # sur_pcl = titanic['pclass'][titanic['survived']==1]
# ----> 2 titanic.columns()
#
# TypeError: 'Index' object is not callable

# %%
# titanic['age']

# %%
# titanic2 = titanic.dropna(subset = ["age", "embarked"])

# %%
# titanic2[titanic2['survived']==1]

# %%
# titanic.drop_duplicates()

# %%
# titanic['pclass'] = titanic['pclass'].astype('category')
# titanic.info()
