# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl                     
import matplotlib.font_manager as fm 
import numpy as np

mpl.rcParams['font.family'] = 'AppleGothic'

# %%
file = pd.read_json('경기도행정구역경계.json')
file.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'code': 313...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'code': 313...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'code': 313...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'code': 312...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'code': 312...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      44 non-null     object
#  1   features  44 non-null     object
# dtypes: object(2)
# memory usage: 836.0+ bytes

# %%
file2 = pd.json_normalize(file["features"], meta=['type'])

file3 = file2["geometry.coordinates"]

print(file3.info(), file3.describe(), file3.shape, file3.ndim, sep='\n\n\n')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 44 entries, 0 to 43
# Series name: geometry.coordinates
# Non-Null Count  Dtype
# --------------  -----
# 44 non-null     object
# dtypes: object(1)
# memory usage: 484.0+ bytes
# None
#
#
# count                                                    44
# unique                                                   44
# top       [[[127.56113535909492, 37.6256560539258], [127...
# freq                                                      1
# Name: geometry.coordinates, dtype: object
#
#
# (44,)
#
#
# 1

# %%
file2
# Out:
#        type  properties.code properties.name  properties.name_eng  \
# 0   Feature            31380             양평군       Yangpyeong-gun
# 1   Feature            31370             가평군         Gapyeong-gun
# 2   Feature            31350             연천군        Yeoncheon-gun
# 3   Feature            31280             여주시             Yeoju-si
# 4   Feature            31270             포천시            Pocheonsi
# 5   Feature            31260             양주시             Yangjusi
# 6   Feature            31250             광주시              Gwangju
# 7   Feature            31240             화성시           Hwaseongsi
# 8   Feature            31230             김포시             Gimpo-si
# 9   Feature            31220             안성시           Anseong-si
# 10  Feature            31210             이천시            Icheon-si
# 11  Feature            31200             파주시              Paju-si
# 12  Feature            31193          용인시수지구       Yonginsisujigu
# ...

# %%
file3
# Out:
# 0     [[[127.56113535909492, 37.6256560539258], [127...
# 1     [[[127.44780328408541, 38.048238751068475], [1...
# 2     [[[127.1114029794941, 38.289324698353205], [12...
# 3     [[[127.40276739880215, 37.41856433413549], [12...
# 4     [[[127.18150182398624, 38.181927191525546], [1...
# 5     [[[126.97545924731331, 37.93928140597955], [12...
# 6     [[[127.30923294884336, 37.5135706079458], [127...
# 7     [[[126.92946761531998, 37.275967848758626], [1...
# 8     [[[126.67862254618308, 37.697305342702336], [1...
# 9     [[[127.4921007211045, 37.04995601187854], [127...
# 10    [[[127.44459662819855, 37.35562085049101], [12...
# 11    [[[126.8029965558113, 37.989251239637596], [12...
# 12    [[[127.03004539569396, 37.36932312139811], [12...
# 13    [[[127.09199113357242, 37.295585212583866], [1...
# 14    [[[127.34092967480524, 37.26770614318737], [12...
# 15    [[[127.16683184366129, 37.57672487388627], [12...
# 16    [[[127.04377994345505, 37.41281928664435], [12...
# ...

# %%
plt.figure(figsize=(10,10))

file3
list2 = []
list3 = []
# list4 = []
# if 
# for i in file3:
#     for x in list1:
#         for y in x:
#             list2.append(y)
#             for z in y:
#                 list3.append(z)
# #                 for a in z:
# #                     list4.append(a)
# list2

# %%
list3
# Out:
# []

# %%
list4
# Out:
# []

# %%
plt.figure(figsize=(10,10))



for x in file3:
    for y in x:
        if type(y[0][0])== list:       # 여기가 제일 핵심
            y = y[0]
        a = [f[0] for f in y]
        b = [f[1] for f in y]
        plt.plot(a,b)
